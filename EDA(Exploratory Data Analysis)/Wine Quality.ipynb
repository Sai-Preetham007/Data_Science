# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/saipr/OneDrive/Desktop/Data_Science/datasets/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# ### Get all the column names

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### Check null values

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Check for duplicates and drop

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True)
df
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         5            7.4             0.660         0.00             1.8
# ...     ...            ...               ...          ...             ...
# 1354   1593            6.8             0.620         0.08             1.9
# 1355   1594            6.2             0.600         0.08             2.0
# 1356   1595            5.9             0.550         0.10             2.2
# 1357   1597            5.9             0.645         0.12             2.0
# 1358   1598            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### co-relation

# %%
df.corr()
# Out:
#                          index  fixed acidity  volatile acidity  citric acid  \
# index                 1.000000      -0.263999         -0.014721    -0.154419
# fixed acidity        -0.263999       1.000000         -0.255124     0.667437
# volatile acidity     -0.014721      -0.255124          1.000000    -0.551248
# citric acid          -0.154419       0.667437         -0.551248     1.000000
# residual sugar       -0.019472       0.111025         -0.002449     0.143892
# chlorides            -0.133904       0.085886          0.055154     0.210195
# free sulfur dioxide   0.077603      -0.140580         -0.020945    -0.048004
# total sulfur dioxide -0.134129      -0.103777          0.071701     0.047358
# density              -0.374347       0.670195          0.023943     0.357962
# pH                    0.147029      -0.686685          0.247111    -0.550310
# sulphates            -0.119986       0.190269         -0.256948     0.326062
# ...

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %% [markdown]
# ### It is an imbalanced dataset

# %%
df["quality"].value_counts()
# Out:
# quality
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: count, dtype: int64

# %%
df["quality"].value_counts().plot(kind="bar", color="violet")
plt.xlabel("Wine Quality")
plt.ylabel("Count")
plt.title("Bar Plot", color="red")
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# ### Categorical Plot

# %%
sns.catplot(kind="box", data=df, x="quality", y="alcohol", color="orange")

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x="alcohol", y="pH", hue="quality", data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
