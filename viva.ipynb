# %%
import random

# %% [markdown]
# # Strings

# %%
strings = ["What is the output of 'Hello'[1:4]?", "What does the strip() method do in a string?",
           "What is the result of 'hello'.replace('l', 'z')?", "How do you reverse a string in Python?",
           "What does the split() method do in a string?", "How do you find the length of a string in Python?",
           "Write a Python code to convert the string 'Hello World' to uppercase.", "What will print('hello' * 3)",
           "How do you replace all occurrences of 'a' with 'o' in the string 'banana'?",
           "Write a Python expression to concatenate 'Hello' and 'World'.", "How do you split the string 'a,b,c' into a list of values?"]

s = random.randrange(len(strings))
strings[s]
# Out:
# 'How do you find the length of a string in Python?'

# %% [markdown]
# # Lists

# %%
lists = ["How do you add an element to the end of a list?", "How do you remove an item by value from a list?",
         "What does the pop() method do in a list?", "What is the output of [1, 2, 3] * 2?",
         "Write a Python code to add the number 10 to a list [1, 2, 3].", "What will print([1, 2, 3] + [4, 5])",
         "Write a Python expression to reverse a list [1, 2, 3].", "What will print([0] * 5)",
         "Check if the number 4 is present in the list [1, 2, 3, 4]?", "Sort the list [5, 2, 8, 1]",
         "Difference between append() and extend() in lists?", "find the index of 'banana' in the list ['apple', 'banana', 'cherry']."]

l = random.randrange(len(lists))
lists[l]
# Out:
# 'Write a Python expression to reverse a list [1, 2, 3].'

# %% [markdown]
# # Tuples

# %%
tuples = ["What is the key difference between a list and a tuple?", "Write a Python code to create a tuple with values 1, 2, 3.",
          "How do you access the second element of the tuple (10, 20, 30)?", "Can you modify a tuple after creating it?"]

t = random.randrange(len(tuples))
tuples[t]
# Out:
# 'Can you modify a tuple after creating it?'

# %% [markdown]
# # Dictionaries

# %%
dictionaries = ["How do you access the value of a key in a dictionary?", "How do you remove a key-value pair from a dictionary?",
                "How do you get all the keys from a dictionary?", "How do you check if a key exists in a dictionary?",
                "What is the output of dict1.update(dict2)?", "Access the value of 'age' in the dictionary {'name': 'Alice', 'age': 25}?",
                "Add a new key 'city' with value 'New York' to the dictionary {'name': 'Alice'}.", "What will print({'a': 1, 'b': 2}.keys())"]

d = random.randrange(len(dictionaries))
dictionaries[d]
# Out:
# 'How do you check if a key exists in a dictionary?'

# %% [markdown]
# # File Handling

# %%
file_handling = ["What is the default mode when opening a file with open()?", "How do you read the contents of a file line by line?",
                 "What does 'w' mode do when opening a file?", "How do you close a file in Python?",
                 "How do you write text to a file in Python?", "What does the read() method do in file handling?"]

f = random.randrange(len(file_handling))
file_handling[f]
# Out:
# 'How do you write text to a file in Python?'

# %% [markdown]
# # Loops

# %%
loops = ["Difference between for and while loops?", "What will range(5) generate?", "What does the 'continue' keyword do in a loop?",
         "What is an infinite loop?", "Can a for loop iterate over a string? (Yes/No)", "Use a while loop to print numbers from 1 to 5?",
         "Write a python code to find the sum of elements in the list [1, 2, 3] using a for loop.", "What will break do in a loop?",
         "Write a Python program to print the multiplication table of 2 using a loop."]

ls = random.randrange(len(loops))
loops[ls]
# Out:
# 'Difference between for and while loops?'

# %% [markdown]
# # Conditions

# %%
conditions = ["What is the syntax for an if statement in Python?",
              "What will if 0: evaluate to?", "What is the output of bool('False') and bool(False)?",
              "How do you check if two conditions are both true?", "What is the result of 5 > 3 and 2 < 1?",
              "What does the elif keyword do in Python?"]

c = random.randrange(len(conditions))
conditions[c]
# Out:
# 'What is the result of 5 > 3 and 2 < 1?'
