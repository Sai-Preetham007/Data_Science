# %%
import pandas as pd
df = pd.read_csv("datasets/data_science_job.csv")
df_copy = df.copy()
df.head()
# Out:
#    work_year                             job_title  job_category  \
# 0       2022  Machine Learning Engineer  in office      Analysis
# 1       2020                Statistician  (Remote)         ML/AI
# 2       2022           Machine Learning Engineer           ML/AI
# 3       2022               Data Analyst  in office         ML/AI
# 4       2020                        Statistician    Data Science
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR  186597         136086                 US               MI
# 1             JPY  110630          67982                 JP               EX
# 2             INR   61280         153309                 UK               MI
# 3             JPY  154130         135242                 DE               SE
# 4             EUR  172312          35156                 UK               MI
#
#   employment_type work_setting company_location company_size
# 0              CT       Remote               DE            L
# 1              FL       Remote               IN            M
# 2              CT       Hybrid               CN            L
# 3              FT       Hybrid               MX            L
# 4              FT    In-person               UK            S

# %%
row,col = df.shape
print(f"Rows : {row} \nColumns : {col}")
# Out:
# Rows : 5000
# Columns : 12

# %%
df.dtypes
# Out:
# work_year              int64
# job_title             object
# job_category          object
# salary_currency       object
# salary                 int64
# salary_in_usd          int64
# employee_residence    object
# experience_level      object
# employment_type       object
# work_setting          object
# company_location      object
# company_size          object
# dtype: object

# %%
df.isna().any()          # df.isnull().any()
# Out:
# work_year             False
# job_title             False
# job_category           True
# salary_currency        True
# salary                False
# salary_in_usd         False
# employee_residence    False
# experience_level       True
# employment_type       False
# work_setting          False
# company_location      False
# company_size           True
# dtype: bool

# %%
df.isna().sum()          # gives total sum of null values in a particular column.
# Out:
# work_year               0
# job_title               0
# job_category          500
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level      500
# employment_type         0
# work_setting            0
# company_location        0
# company_size          500
# dtype: int64

# %%
df.head()
# Out:
#    work_year                             job_title  job_category  \
# 0       2022  Machine Learning Engineer  in office      Analysis
# 1       2020                Statistician  (Remote)         ML/AI
# 2       2022           Machine Learning Engineer           ML/AI
# 3       2022               Data Analyst  in office         ML/AI
# 4       2020                        Statistician    Data Science
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR  186597         136086                 US               MI
# 1             JPY  110630          67982                 JP               EX
# 2             INR   61280         153309                 UK               MI
# 3             JPY  154130         135242                 DE               SE
# 4             EUR  172312          35156                 UK               MI
#
#   employment_type work_setting company_location company_size
# 0              CT       Remote               DE            L
# 1              FL       Remote               IN            M
# 2              CT       Hybrid               CN            L
# 3              FT       Hybrid               MX            L
# 4              FT    In-person               UK            S

# %%
df["salary_currency"].unique()
# Out:
# array(['EUR', 'JPY', 'INR', nan, 'us dolars', 'GBP'], dtype=object)

# %% [markdown]
# ### Converting "salary_in_usd" to INR

# %%
df["USD_to_INR"] = df["salary_in_usd"]*84.39
df.head()
# Out:
#    work_year                             job_title  job_category  \
# 0       2022  Machine Learning Engineer  in office      Analysis
# 1       2020                Statistician  (Remote)         ML/AI
# 2       2022           Machine Learning Engineer           ML/AI
# 3       2022               Data Analyst  in office         ML/AI
# 4       2020                        Statistician    Data Science
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR  186597         136086                 US               MI
# 1             JPY  110630          67982                 JP               EX
# 2             INR   61280         153309                 UK               MI
# 3             JPY  154130         135242                 DE               SE
# 4             EUR  172312          35156                 UK               MI
#
#   employment_type work_setting company_location company_size   USD_to_INR
# 0              CT       Remote               DE            L  11484297.54
# 1              FL       Remote               IN            M   5737000.98
# 2              CT       Hybrid               CN            L  12937746.51
# 3              FT       Hybrid               MX            L  11413072.38
# 4              FT    In-person               UK            S   2966814.84

# %% [markdown]
# ### Drop Columns

# %%
df = df.drop("salary_in_usd", axis=1).drop("salary_currency", axis=1).drop("salary", axis=1)
df.head()
# Out:
#    work_year                             job_title  job_category  \
# 0       2022  Machine Learning Engineer  in office      Analysis
# 1       2020                Statistician  (Remote)         ML/AI
# 2       2022           Machine Learning Engineer           ML/AI
# 3       2022               Data Analyst  in office         ML/AI
# 4       2020                        Statistician    Data Science
#
#   employee_residence experience_level employment_type work_setting  \
# 0                 US               MI              CT       Remote
# 1                 JP               EX              FL       Remote
# 2                 UK               MI              CT       Hybrid
# 3                 DE               SE              FT       Hybrid
# 4                 UK               MI              FT    In-person
#
#   company_location company_size   USD_to_INR
# 0               DE            L  11484297.54
# 1               IN            M   5737000.98
# 2               CN            L  12937746.51
# 3               MX            L  11413072.38
# 4               UK            S   2966814.84

# %% [markdown]
# ### Rename Column

# %%
df = df.rename(columns={"work_year" : "year", "USD_to_INR" : "salary_in_INR", "work_setting" : "work_type"})
df.head()
# Out:
#    year                             job_title  job_category  \
# 0  2022  Machine Learning Engineer  in office      Analysis
# 1  2020                Statistician  (Remote)         ML/AI
# 2  2022           Machine Learning Engineer           ML/AI
# 3  2022               Data Analyst  in office         ML/AI
# 4  2020                        Statistician    Data Science
#
#   employee_residence experience_level employment_type  work_type  \
# 0                 US               MI              CT     Remote
# 1                 JP               EX              FL     Remote
# 2                 UK               MI              CT     Hybrid
# 3                 DE               SE              FT     Hybrid
# 4                 UK               MI              FT  In-person
#
#   company_location company_size  salary_in_INR
# 0               DE            L    11484297.54
# 1               IN            M     5737000.98
# 2               CN            L    12937746.51
# 3               MX            L    11413072.38
# 4               UK            S     2966814.84

# %%
df["job_title"].unique()
# Out:
# array(['Machine Learning Engineer  in office', 'Statistician  (Remote)',
#        'Machine Learning Engineer  ', 'Data Analyst  in office',
#        'Statistician  ', 'Data Scientist  (Remote)', 'Data Analyst  ',
#        'Data Engineer  in office', 'Data Scientist  ',
#        'Machine Learning Engineer  (Remote)', 'Data Engineer  ',
#        'Data Engineer  (Remote)', 'Data Scientist  in office',
#        'Data Analyst  (Remote)', 'Statistician  in office'], dtype=object)

# %%
df = df.map(lambda x:x.strip() if isinstance(x, str) else x)
df.head()
# Out:
#    year                             job_title  job_category  \
# 0  2022  Machine Learning Engineer  in office      Analysis
# 1  2020                Statistician  (Remote)         ML/AI
# 2  2022             Machine Learning Engineer         ML/AI
# 3  2022               Data Analyst  in office         ML/AI
# 4  2020                          Statistician  Data Science
#
#   employee_residence experience_level employment_type  work_type  \
# 0                 US               MI              CT     Remote
# 1                 JP               EX              FL     Remote
# 2                 UK               MI              CT     Hybrid
# 3                 DE               SE              FT     Hybrid
# 4                 UK               MI              FT  In-person
#
#   company_location company_size  salary_in_INR
# 0               DE            L    11484297.54
# 1               IN            M     5737000.98
# 2               CN            L    12937746.51
# 3               MX            L    11413072.38
# 4               UK            S     2966814.84

# %%
df.job_title.unique()
# Out:
# array(['Machine Learning Engineer  in office', 'Statistician  (Remote)',
#        'Machine Learning Engineer', 'Data Analyst  in office',
#        'Statistician', 'Data Scientist  (Remote)', 'Data Analyst',
#        'Data Engineer  in office', 'Data Scientist',
#        'Machine Learning Engineer  (Remote)', 'Data Engineer',
#        'Data Engineer  (Remote)', 'Data Scientist  in office',
#        'Data Analyst  (Remote)', 'Statistician  in office'], dtype=object)

# %% [markdown]
# ### Filtering records with "job_title" = "Data Engineer" and "experience_level" = "EN(Entry Level)"

# %%
temp = df[(df["job_title"]=="Data Engineer") & (df["experience_level"]=="EN")]
temp
# Out:
#       year      job_title  job_category employee_residence experience_level  \
# 14    2021  Data Engineer      Analysis                 JP               EN
# 218   2020  Data Engineer   Engineering                 CN               EN
# 256   2021  Data Engineer      Analysis                 US               EN
# 266   2022  Data Engineer  Data Science                 US               EN
# 316   2021  Data Engineer         ML/AI                 UK               EN
# ...    ...            ...           ...                ...              ...
# 4796  2020  Data Engineer         ML/AI                 DE               EN
# 4822  2021  Data Engineer      Analysis                 MX               EN
# 4861  2021  Data Engineer   Engineering                 JP               EN
# 4897  2020  Data Engineer   Engineering                 UK               EN
# 4933  2022  Data Engineer         ML/AI                 US               EN
#
#      employment_type  work_type company_location company_size  salary_in_INR
# 14                FT     Hybrid               CN            M     9113107.32
# 218               CT     Hybrid               UK            M     8297731.14
# 256               PT  In-person               UK            M    15645062.10
# 266               FL     Remote               CN            S    14563604.25
# 316               FT     Remote               US            L     5735313.18
# ...              ...        ...              ...          ...            ...
# 4796              FL     Remote               JP            M     5532945.96
# 4822              CT     Remote               CN            M     8606598.54
# 4861              FT     Hybrid               UK            S    15979415.28
# 4897              FL     Hybrid               MX            S    13371004.77
# 4933              FL     Remote               JP            L     7294334.04
#
# [64 rows x 10 columns]

# %% [markdown]
# ### Average Salary of Data Engineer(Entry Level)

# %%
print(f"Average Salary : {temp["salary_in_INR"].mean()}rs")
# Out:
# Average Salary : 9257548.7165625rs

# %% [markdown]
# ### Grouping by job_category

# %%
salary_by_job_category = temp.groupby("job_category")["salary_in_INR"].sum()
salary_by_job_category
# Out:
# job_category
# Analysis        1.434570e+08
# Data Science    1.702042e+08
# Engineering     1.572641e+08
# ML/AI           1.215579e+08
# Name: salary_in_INR, dtype: float64

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [i for i in range(11)]
y = [i**3 for i in range(11)]

plt.plot(x,y)

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Cube of a Number")
# Out:
# Text(0.5, 1.0, 'Cube of a Number')

# %%
x = [i for i in range(11)]
y = [i**2 for i in range(11)]

plt.plot(x,y, color="red", linestyle="--", marker="o", markersize=10, linewidth=2)
plt.grid(True)

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Square of a Number")
# Out:
# Text(0.5, 1.0, 'Square of a Number')

# %% [markdown]
# ### subplot

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
z = [1,8,27,64,125]

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)            # row = 2, column = 2, position = 1
plt.plot(x,y, color="red", marker="o")
plt.title("Plot 1")

plt.subplot(2,2,2)
plt.plot(y,x, color="blue", marker="o")
plt.title("Plot 2")

plt.subplot(2,2,3)
plt.plot(x,z, color="green", marker="o")
plt.title("Plot 3")

plt.subplot(2,2,4)
plt.plot(z,x, color="violet", marker="o")
plt.title("Plot 4")
# Out:
# Text(0.5, 1.0, 'Plot 4')

# %% [markdown]
# ### Barplot

# %%
categories = ["A", "B", "C", "D", "E"]
values = [5,7,3,8,6]

plt.bar(categories, values, color="violet")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### Histogram
# * It is used to represent the distribution of dataset. They divide the data into bins and count the number of data points in each bin.
# * Simply known as total no of values in a particular range of intervals based on bin size.

# %%
data = [1,2,2,3,3,3,4,4,5,5,5,5]
plt.hist(data, bins=5, color="yellow", edgecolor="black")
# Out:
# (array([1., 2., 3., 2., 4.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ### Scatter plot
# * without out any line

# %%
x = [1,2,3,4,5]
plt.scatter(x,x, color="red", marker="x")

# %% [markdown]
# ### Pie Chart

# %%
labels = ["A", "B", "C", "D", "E"]
values = [15, 57, 13, 36, 6]
colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue", "violet"]
explode = (0.2,0,0,0,0)

plt.pie(values,labels=labels, colors=colors, autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1bbd98d04d0>,
#   <matplotlib.patches.Wedge at 0x1bbd9a685c0>,
#   <matplotlib.patches.Wedge at 0x1bbd9ab1040>,
#   <matplotlib.patches.Wedge at 0x1bbd99f9eb0>,
#   <matplotlib.patches.Wedge at 0x1bbd9ab16a0>],
#  [Text(1.0251401491869723, 0.3988579628450614, 'A'),
#   Text(-0.604038788584402, 0.9193134078677894, 'B'),
#   Text(-0.8107499278716709, -0.7434275717620921, 'C'),
#   Text(0.4115066808932634, -1.0201285465960699, 'D'),
#   Text(1.0879062929344288, -0.1626649863789663, 'E')],
#  [Text(0.5591673541019848, 0.21755888882457894, '11.81%'),
#   Text(-0.3294757028642192, 0.5014436770187941, '44.88%'),
#   Text(-0.4422272333845477, -0.4055059482338684, '10.24%'),
#   Text(0.22445818957814365, -0.5564337526887654, '28.35%'),
#   Text(0.5934034325096883, -0.08872635620670886, '4.72%')])

# %%
labels = ["A", "B", "C", "D", "E"]
values = [15, 57, 13, 36, 6]
colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue", "violet"]
explode = (0.2,0,0,0,0)

plt.pie(values,labels=labels, explode=explode, colors=colors, autopct="%.2f%%")
plt.show()             # the additional info will not be shown in the output.

# %% [markdown]
# ### From the above example (16th cell)

# %%
salary_by_job_category
# Out:
# job_category
# Analysis        1.434570e+08
# Data Science    1.702042e+08
# Engineering     1.572641e+08
# ML/AI           1.215579e+08
# Name: salary_in_INR, dtype: float64

# %% [markdown]
# ### To use plt.bar(), we require x axis data and y axis data

# %%
# plt.bar(salary_by_job_category)

# %%
salary_by_job_category.plot(kind="bar", color="cyan")
# Out:
# <Axes: xlabel='job_category'>

# %% [markdown]
# ### Reset Index

# %%
temp1 = salary_by_job_category.reset_index()
temp1
# Out:
#    job_category  salary_in_INR
# 0      Analysis   1.434570e+08
# 1  Data Science   1.702042e+08
# 2   Engineering   1.572641e+08
# 3         ML/AI   1.215579e+08

# %%
plt.bar(temp1["job_category"], temp1["salary_in_INR"], color="magenta")
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Basic plotting with seaborn

# %% [markdown]
# * load_dataset ---> It is an inbuilt function for seaborn
# * tips ---> it is also present in it.

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.title("Total Bill vs Tip", color="Red")
plt.show()

# %%
sns.lineplot(data=tips, x="size", y="total_bill")
plt.title("Total Bill vs Size", color="red")
plt.show()

# %%
sns.barplot(data=tips, x="day", y="total_bill")
plt.title("Total Bill by Day", color="red")
plt.show()

# %% [markdown]
# ### Box plot
# * It is similar to candle stick pattern in stocks, Here
# * bottom wick = min value
# * top wick = max value
# * candle bottom = 25%
# * candle top = 75%
# * middle line = 50%

# %%
sns.boxplot(data=tips, x="day", y="total_bill")
plt.title("Total Bill by Day", color="red")
plt.show()

# %% [markdown]
# ### Violin plot
# * It gives additional information to box plot

# %%
sns.violinplot(data=tips, x="day", y="total_bill")
plt.title("Total Bill by Day", color="red")
plt.show()

# %% [markdown]
# ### Histogram plot

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
sns.histplot(tips["total_bill"])
plt.title("Histogram", color="red")

plt.subplot(1,3,2)
sns.histplot(tips["total_bill"], bins=10)    # bins = 10 the total divisions on x-axis is 10
plt.title("Histogram with bins", color="red")

plt.subplot(1,3,3)
sns.histplot(tips["total_bill"], bins=10, kde=True)    # kde ---> Kernal Density Estimation
plt.title("Histogram with bins and kde", color="red")

plt.show()

# %% [markdown]
# ### KDE plot
# * kernel Density Estimation

# %%
plt.figure(figsize=(12,3))

plt.subplot(1,2,1)
sns.kdeplot(tips["total_bill"])

plt.subplot(1,2,2)
sns.kdeplot(tips["total_bill"], fill=True)

plt.show()

# %% [markdown]
# ### Pair plot
# * It gives all the plots of the numerical data of each column in a dataframe.

# %%
sns.pairplot(tips)
plt.show()

# %% [markdown]
# ### Heatmap

# %%
corr_df = tips[["total_bill", "tip", "size"]].corr()
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
sns.heatmap(corr_df)
plt.title("Heatmap", color="red")

plt.subplot(1,3,2)
sns.heatmap(corr_df, annot=True)
plt.title("Heatmap with annotation", color="red")

plt.subplot(1,3,3)
sns.heatmap(corr_df, annot=True, cmap="coolwarm")
plt.title("Heatmap with annotation and colormap", color="red")

plt.show()
